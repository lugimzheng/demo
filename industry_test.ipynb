# %% [markdown]
# 代码执行程序->更改运行时类型->GPU

# %%
import sys
print('Your python version: {}'.format(sys.version_info.major))
import os
# Out:
# Your python version: 3

# %%
import os
path = '/content/drive/MyDrive/industry/demo/'
os.chdir(path)

# %%
! pip install git+https://github.com/ageitgey/face_recognition_models
# Out:
# ...
#   Cloning https://github.com/ageitgey/face_recognition_models to /tmp/pip-req-build-nwf78tya
#   Running command git clone -q https://github.com/ageitgey/face_recognition_models /tmp/pip-req-build-nwf78tya
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566173 sha256=a9683669eaab70031131e112138aa3522f3e70239f0935b4dab93596f5188486
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8ar7ld95/wheels/0e/43/bc/eeadfb1a85c256c03f93bd26b361adc3ff0d2a8e7f1b481a80
# Successfully built face-recognition-models

# %%
! python face_database.py

# %%
#run the file: python yolov3_deepsort.py rgb_video_path depth_video_path
#in colab, if you want to run any bash command add an '!' before it
#The output video is in demo/output/ 
! python yolov3_deepsort.py '/content/drive/MyDrive/video/two/3_rgb.avi' '/content/drive/MyDrive/video/two/3_d.avi' 'db.npz'
# Out:
# 2020-12-31 06:57:51 [INFO]: Loading weights from ./detector/YOLOv3/weight/yolov3.weights... Done!
# 2020-12-31 06:57:56 [INFO]: Loading weights from ./deep_sort/deep/checkpoint/ckpt.t7... Done!
# 2020-12-31 06:57:56 [INFO]: Save results to ./output/
# 2020-12-31 06:57:56 [INFO]: time: 0.077s, fps: 12.906, detection numbers: 2, tracking numbers: 0
# 2020-12-31 06:57:56 [INFO]: time: 0.073s, fps: 13.737, detection numbers: 2, tracking numbers: 0
# 2020-12-31 06:57:59 [INFO]: time: 2.741s, fps: 0.365, detection numbers: 2, tracking numbers: 2
# 2020-12-31 06:57:59 [INFO]: time: 0.920s, fps: 1.087, detection numbers: 2, tracking numbers: 2
# 2020-12-31 06:58:00 [INFO]: time: 0.915s, fps: 1.093, detection numbers: 2, tracking numbers: 2
# 2020-12-31 06:58:01 [INFO]: time: 0.936s, fps: 1.069, detection numbers: 2, tracking numbers: 2
# 2020-12-31 06:58:02 [INFO]: time: 0.926s, fps: 1.079, detection numbers: 2, tracking numbers: 2
# ...

# %%
# !nvidia-smi
# Out:
# Wed Dec 30 12:21:52 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.27.04    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8    11W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import cv2
path = '/content/1_d.png'
import matplotlib.pyplot as plt # plt 用于显示图片
import matplotlib.image as mpimg # mpimg 用于读取图片
import numpy as np
 
lena = mpimg.imread(path) # 读取和代码处于同一目录下的 lena.png
# 此时 lena 就已经是一个 np.array 了，可以对它进行任意处理
print(lena.shape)
a =  np.stack((lena, lena, lena), axis=2)
print(a.shape)
plt.imshow(lena) # 显示图片
plt.axis('off') # 不显示坐标轴
plt.show()
# Out:
# (480, 640)
# (480, 640, 3)
